# %%
import sys
sys.path.append('/Users/akeow/Desktop/TEAMER HDPS/HDPSTeamer/TurboShipCostCalculator/')

import constVessel # module for creating vessel

# %% [markdown]
# constVessel constaint the function 'create_vessel' which can be used to create new vessel.
#
# The input into the function must follow the order below.

# %%
Name = "MyShip"     # Name of the vessel
Xm = 10.0             # Horizontal distance from CG to mooring line [meter]
Zm = 1.0              # Vertical distance from CG to mooring line [meter]
Km = 100.0e6          # Pitch stiffness
theta = 45.0          # Mooring line angle [degree]
phi = 10.0            # Vessel pitch constraint [degree]
area = 15.0           # Area of the vessel
Cd = 1.0              # Vessel drag coefficient 

NewBoat = constVessel.create_vessel(Name,Xm,Zm,Km,theta,phi,area,Cd)

# %% [markdown]
# Print Vessel Details to verify that vessel is created correctly

# %%
constVessel.print_vessel_details(NewBoat)
# Out:
# name: MyShip
# X_m: 10.0
# Z_m: 1.0
# K_m: 100000000.0
# theta: 45.0
# phi: 10.0
# area: 15.0
# Cd: 1.0
