# %%
import numpy as np
import sys
import os
import pickle
import re
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.colors as mcolors


# Define the path to the src directory manually
src_path = os.path.abspath('../../../src')
sys.path.insert(0, src_path)

from module_tidal import TidalData
from module_rotor import RotorData
from module_rotor_simulation import RotorSimulation
from module_vessel import VesselData
from module_lcoe import LCOE
from module_constraint_checker import ConstraintChecker
from module_battery_charging import BatteryCharging

from constUnitConvert import ConstantsUnitConversion
from constGlobal import ConstantsGlobal

CONVERT = ConstantsUnitConversion()
GLOBAL = ConstantsGlobal()

rotor_filename = "../../../data/Sitkana_rotor_data_blade_1.txt"
rotor_data = RotorData(rotor_filename)

station = "PCT3716"  # Site 2
startdate = 20200201  # yyyyMMdd
rangeHr = 2 * 7 * 24  # Two weeks
timestep = 5.0  # Timestep in seconds

tidal_data = TidalData(station, startdate, rangeHr, timestep)
# /Users/akeow/Desktop/VITAL/HDPS_TeamerClean/sitkana/Fixed Vessel Cases/Site 1 Speed/
# /Users/akeow/Desktop/VITAL/HDPS_TeamerClean
flow_speeds, times, dmoor_m, lat_rad, lon_rad, station_name, nearest_city, cable_length = tidal_data.load_tidal_data("../../../data/AlaskaCityLatLong.txt")

plt.plot(times/(24*3600),flow_speeds)
plt.xlabel('Days')
plt.ylabel('Flow [m/s]')
plt.title(station)


plt.tight_layout()
file_name = f'flow_{station}.png'
plt.savefig(file_name)
plt.show()
# Out:
# /Users/akeow/opt/anaconda3/envs/VITAL_env/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'proxy.sandia.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/akeow/opt/anaconda3/envs/VITAL_env/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'proxy.sandia.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/akeow/opt/anaconda3/envs/VITAL_env/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'proxy.sandia.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Buoy lat:56.6765 degree
# Buoy lon:-133.7325 degree
# City lat:56.9653 degree
# City lon:-134.1564 degree
# City lat:0.9942320443863258 radian
# City lon:-2.3414708926225205 radian
# Buoy lat:0.9891915335065662 radian
# Buoy lon:-2.3340724419233165 radian

# %%
# Test user-defined vessel properties (Fishing vessel)
user_vessel_properties = {
    'Xm': 5.77,
    'Zm': 1.65,
    'Kphi': 1.95e6,
    'theta': 45.0 * np.pi / 180.0,
    'phi': 10.0 * np.pi / 180.0,
    'area': 2.25,
    'Cd': 1.0
}

# initialize classes
vessel = VesselData(
    user_defined=True,
    vessel_properties=user_vessel_properties
)

vessel.print_all_attributes()



BatteryCapacity_kWh = 10  # kWh
turbulence_intensity = 0.0
discount_rate = 0.01
lifetime = 10
BatteryCapacity_kWh = 20
# Out:
# height: None
# density: None
# theta_m: 0.7853981633974483
# alpha: None
# Cd: 1.0
# phi: 0.17453292519943295
# user_defined: True
# vessel_properties: {'Xm': 5.77, 'Zm': 1.65, 'Kphi': 1950000.0, 'theta': 0.7853981633974483, 'phi': 0.17453292519943295, 'area': 2.25, 'Cd': 1.0}
# width: None
# Fmoor: None
# length: None
# Khs: None
# Kphi: 1950000.0
# GM: None
# VesselVolume: None
# h_s: None
# Xm: 5.77
# Zm: 1.65
# area: 2.25

# %%
# Directory where the .pkl files are saved (current directory)
output_directory = os.getcwd()

# List all .pkl files in the directory
pkl_files = [f for f in os.listdir(output_directory) if f.endswith('.pkl')]
pkl_files
# Out:
# ['simulation_results_R1.0_P5000.0_D6.0.pkl',
#  'simulation_results_R2.0_P20000.0_D18.0.pkl',
#  'simulation_results_R1.0_P20000.0_D14.0.pkl',
#  'simulation_results_R1.0_P1000.0_D6.0.pkl',
#  'simulation_results_R1.5_P10000.0_D18.0.pkl',
#  'simulation_results_R0.5_P20000.0_D14.0.pkl',
#  'simulation_results_R1.5_P5000.0_D18.0.pkl',
#  'simulation_results_R0.5_P5000.0_D18.0.pkl',
#  'simulation_results_R2.0_P5000.0_D18.0.pkl',
#  'simulation_results_R0.5_P20000.0_D10.0.pkl',
#  'simulation_results_R1.0_P5000.0_D18.0.pkl',
#  'simulation_results_R2.0_P1000.0_D6.0.pkl',
#  'simulation_results_R1.0_P20000.0_D10.0.pkl',
#  'simulation_results_R2.0_P5000.0_D6.0.pkl',
#  'simulation_results_R1.5_P20000.0_D14.0.pkl',
#  'simulation_results_R0.5_P10000.0_D18.0.pkl',
#  'simulation_results_R2.0_P10000.0_D14.0.pkl',
#  'simulation_results_R1.0_P10000.0_D18.0.pkl',
#  'simulation_results_R2.0_P10000.0_D10.0.pkl',
#  'simulation_results_R1.0_P1000.0_D18.0.pkl',
#  'simulation_results_R1.5_P5000.0_D6.0.pkl',
#  'simulation_results_R2.0_P1000.0_D18.0.pkl',
#  'simulation_results_R0.5_P1000.0_D18.0.pkl',
#  'simulation_results_R1.5_P20000.0_D10.0.pkl',
#  'simulation_results_R1.5_P1000.0_D6.0.pkl',
#  'simulation_results_R1.5_P1000.0_D18.0.pkl',
#  'simulation_results_R1.5_P1000.0_D14.0.pkl',
#  'simulation_results_R0.5_P10000.0_D10.0.pkl',
#  'simulation_results_R0.5_P1000.0_D14.0.pkl',
#  'simulation_results_R2.0_P1000.0_D14.0.pkl',
#  'simulation_results_R0.5_P1000.0_D6.0.pkl',
#  'simulation_results_R1.0_P1000.0_D14.0.pkl',
#  'simulation_results_R0.5_P5000.0_D6.0.pkl',
#  'simulation_results_R1.0_P10000.0_D10.0.pkl',
#  'simulation_results_R1.0_P10000.0_D14.0.pkl',
#  'simulation_results_R2.0_P10000.0_D18.0.pkl',
#  'simulation_results_R1.5_P10000.0_D6.0.pkl',
#  'simulation_results_R1.0_P1000.0_D10.0.pkl',
#  'simulation_results_R2.0_P10000.0_D6.0.pkl',
#  'simulation_results_R0.5_P10000.0_D6.0.pkl',
#  'simulation_results_R0.5_P1000.0_D10.0.pkl',
#  'simulation_results_R1.0_P10000.0_D6.0.pkl',
#  'simulation_results_R2.0_P1000.0_D10.0.pkl',
#  'simulation_results_R0.5_P10000.0_D14.0.pkl',
#  'simulation_results_R1.5_P1000.0_D10.0.pkl',
#  'simulation_results_R1.5_P20000.0_D18.0.pkl',
#  'simulation_results_R1.0_P5000.0_D14.0.pkl',
#  'simulation_results_R2.0_P20000.0_D10.0.pkl',
#  'simulation_results_R2.0_P5000.0_D14.0.pkl',
#  'simulation_results_R1.5_P10000.0_D10.0.pkl',
#  'simulation_results_R0.5_P5000.0_D14.0.pkl',
#  'simulation_results_R1.5_P5000.0_D14.0.pkl',
#  'simulation_results_R0.5_P20000.0_D6.0.pkl',
#  'simulation_results_R2.0_P20000.0_D6.0.pkl',
#  'simulation_results_R1.5_P5000.0_D10.0.pkl',
#  'simulation_results_R0.5_P20000.0_D18.0.pkl',
#  'simulation_results_R2.0_P5000.0_D10.0.pkl',
#  'simulation_results_R1.5_P20000.0_D6.0.pkl',
#  'simulation_results_R1.5_P10000.0_D14.0.pkl',
#  'simulation_results_R0.5_P5000.0_D10.0.pkl',
#  'simulation_results_R1.0_P20000.0_D18.0.pkl',
#  'simulation_results_R2.0_P20000.0_D14.0.pkl',
#  'simulation_results_R1.0_P5000.0_D10.0.pkl',
#  'simulation_results_R1.0_P20000.0_D6.0.pkl']

# %%
# Regular expression pattern to extract radius, prated, and dcable values
pattern = re.compile(r'simulation_results_R([0-9.]+)_P([0-9.]+)_D([0-9.]+)\.pkl')

# List of number of turbines to loop through
number_of_turbines_list = [1,2,4,6,8,10,12]

# Read the contents of each .pkl file
stored_results = []
for number_of_turbines in number_of_turbines_list:
    for pkl_file in pkl_files:
        match = pattern.match(pkl_file)
        if match:
            radius = float(match.group(1))
            prated = float(match.group(2))
            dcable = float(match.group(3))

            file_path = os.path.join(output_directory, pkl_file)
            with open(file_path, 'rb') as f:
                result = pickle.load(f)

                # plt.plot(result['t'],result['Pelec'])
                # plt.show()

                constraint_checker = ConstraintChecker(radius, rotor_data.get_cpmin)

                depth_constraint_satisfied = constraint_checker.check_depth_constraint(result['dHub'])
                cavitation_constraint_satisfied = constraint_checker.check_cavitation_constraint(result['TSR'], result['Uinf_adjusted'], result['w'], result['dHub'])
                pitch_constraint_satisfied = constraint_checker.check_pitch_constraint(vessel, result['Uinf_adjusted'], result['Ft'], result['dHub'], number_of_turbines)

                if depth_constraint_satisfied and cavitation_constraint_satisfied and pitch_constraint_satisfied:
                    Vessel_Drag_Force = vessel.calculate_vessel_drag_force(result['Uinf_adjusted'])

                    turbine_radius = radius
                    turbine_rated_power = prated
                    dHub_m = result['dHub']

                    # Create an instance of the LCOE class
                    lcoe_calculator = LCOE(
                                            turbine_radius=turbine_radius, 
                                            turbine_rated_power=turbine_rated_power, 
                                            number_of_turbines=number_of_turbines, 
                                            hub_depth=result['dHub'], 
                                            lifetime=lifetime,
                                            discount_rate=discount_rate,
                                            turbulence_intensity=turbulence_intensity,
                                            customer='customer_B', 
                                            application='battery_charging'
                                           )
                    total_capex, capex_list = lcoe_calculator.calculate_total_capex(cable_length, 
                                                                                    dmoor_m, 
                                                                                    Vessel_Drag_Force, 
                                                                                    result['Ft'], 
                                                                                    vessel.VesselVolume, 
                                                                                    BatteryCapacity_kWh)

                    # Set instantaneous power data
                    lcoe_calculator.set_instantaneous_power(result['Pelec'], result['t'])

                    # Calculate LCOE
                    lcoe = lcoe_calculator.calculate_lcoe(cable_length, 
                                                          dmoor_m, 
                                                          Vessel_Drag_Force, 
                                                          result['Ft'], 
                                                          vessel.VesselVolume, 
                                                          BatteryCapacity_kWh)
                    
                    annual_energy = lcoe_calculator.calculate_annual_energy()
                    capacity_factor = lcoe_calculator.calculate_capacity_factor()

                    dHub_min = np.min(result['dHub'])

                    battery_charging = BatteryCharging(BatteryCapacity_kWh, number_of_turbines, turbulence_intensity)
                    num_batteries_charged, charge_times_hr = battery_charging.chargeBattery_continuous(result['Pelec'], result['t'], visualise=False)
                    charge_time_average = np.average(charge_times_hr)

                    stored_results.append({
                        'radius': radius,
                        'prated': prated,
                        'dcable': dcable,
                        'dHub_min': dHub_min,
                        'lcoe': lcoe,
                        'capex_list': capex_list,
                        'annual_energy': annual_energy,
                        'capacity_factor': capacity_factor,
                        'num_batteries_charged': num_batteries_charged,
                        'charge_time_average': charge_time_average,
                        'number_of_turbines': number_of_turbines,
                        'data': result,
                    })

# Create a DataFrame to store the results
results_df = pd.DataFrame(stored_results, columns=['radius', 'prated', 'dcable','dHub_min','lcoe','number_of_turbines',
                                                   'annual_energy','capacity_factor','num_batteries_charged','charge_time_average', 'capex_list'])

# Expand the capex_list dictionary into separate columns
capex_df = results_df['capex_list'].apply(pd.Series)

# Concatenate the original DataFrame with the expanded capex DataFrame
results_df = pd.concat([results_df.drop(columns=['capex_list']), capex_df], axis=1)
# Out:
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $206.54
# charge_controller_cost: $840.14
# gearbox_cost: $379.96
# concrete_cost: $26.75
# assembly_cost: $329.03
# generator_cost: $1145.13
# rotor_cost: $503.43
# steel_component_cost: $273.04
# rotor_construction_cost: $214.85
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $443.54
# charge_controller_cost: $1392.58
# gearbox_cost: $546.83
# concrete_cost: $106.44
# assembly_cost: $798.77
# generator_cost: $3493.87
# rotor_cost: $1752.86
# steel_component_cost: $663.05
# rotor_construction_cost: $582.83
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $443.54
# charge_controller_cost: $1392.58
# gearbox_cost: $546.83
# concrete_cost: $106.44
# assembly_cost: $798.77
# generator_cost: $3493.87
# rotor_cost: $503.43
# steel_component_cost: $273.04
# rotor_construction_cost: $214.85
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $285.54
# charge_controller_cost: $1116.36
# gearbox_cost: $463.40
# concrete_cost: $52.98
# assembly_cost: $507.62
# generator_cost: $2038.10
# rotor_cost: $1058.14
# steel_component_cost: $457.33
# rotor_construction_cost: $400.79
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $443.54
# charge_controller_cost: $1392.58
# gearbox_cost: $546.83
# concrete_cost: $106.44
# assembly_cost: $798.77
# generator_cost: $3493.87
# rotor_cost: $88.72
# steel_component_cost: $110.18
# rotor_construction_cost: $25.00
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $206.54
# charge_controller_cost: $840.14
# gearbox_cost: $379.96
# concrete_cost: $26.75
# assembly_cost: $329.03
# generator_cost: $1145.13
# rotor_cost: $1058.14
# steel_component_cost: $457.33
# rotor_construction_cost: $400.79
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $206.54
# charge_controller_cost: $840.14
# gearbox_cost: $379.96
# concrete_cost: $26.75
# assembly_cost: $329.03
# generator_cost: $1145.13
# rotor_cost: $88.72
# steel_component_cost: $110.18
# rotor_construction_cost: $25.00
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $443.54
# charge_controller_cost: $1392.58
# gearbox_cost: $546.83
# concrete_cost: $106.44
# assembly_cost: $798.77
# generator_cost: $3493.87
# rotor_cost: $88.72
# steel_component_cost: $110.18
# rotor_construction_cost: $25.00
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $206.54
# charge_controller_cost: $840.14
# gearbox_cost: $379.96
# concrete_cost: $26.75
# assembly_cost: $329.03
# generator_cost: $1145.13
# rotor_cost: $503.43
# steel_component_cost: $273.04
# rotor_construction_cost: $214.85
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $443.54
# charge_controller_cost: $1392.58
# gearbox_cost: $546.83
# concrete_cost: $106.44
# assembly_cost: $798.77
# generator_cost: $3493.87
# rotor_cost: $503.43
# steel_component_cost: $273.04
# rotor_construction_cost: $214.85
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $443.54
# charge_controller_cost: $1392.58
# gearbox_cost: $546.83
# concrete_cost: $106.44
# assembly_cost: $798.77
# generator_cost: $3493.87
# rotor_cost: $1058.14
# steel_component_cost: $457.33
# rotor_construction_cost: $400.79
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $285.54
# charge_controller_cost: $1116.36
# gearbox_cost: $463.40
# concrete_cost: $52.98
# assembly_cost: $507.62
# generator_cost: $2038.10
# rotor_cost: $88.72
# steel_component_cost: $110.18
# rotor_construction_cost: $25.00
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $285.54
# charge_controller_cost: $1116.36
# gearbox_cost: $463.40
# concrete_cost: $52.98
# assembly_cost: $507.62
# generator_cost: $2038.10
# rotor_cost: $503.43
# steel_component_cost: $273.04
# rotor_construction_cost: $214.85
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $143.34
# charge_controller_cost: $198.78
# gearbox_cost: $186.22
# concrete_cost: $6.00
# assembly_cost: $170.30
# generator_cost: $351.50
# rotor_cost: $503.43
# steel_component_cost: $273.04
# rotor_construction_cost: $214.85
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $143.34
# charge_controller_cost: $198.78
# gearbox_cost: $186.22
# concrete_cost: $6.00
# assembly_cost: $170.30
# generator_cost: $351.50
# rotor_cost: $88.72
# steel_component_cost: $110.18
# rotor_construction_cost: $25.00
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $443.54
# charge_controller_cost: $1392.58
# gearbox_cost: $546.83
# concrete_cost: $106.44
# assembly_cost: $798.77
# generator_cost: $3493.87
# rotor_cost: $1058.14
# steel_component_cost: $457.33
# rotor_construction_cost: $400.79
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $285.54
# charge_controller_cost: $1116.36
# gearbox_cost: $463.40
# concrete_cost: $52.98
# assembly_cost: $507.62
# generator_cost: $2038.10
# rotor_cost: $88.72
# steel_component_cost: $110.18
# rotor_construction_cost: $25.00
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $143.34
# charge_controller_cost: $198.78
# gearbox_cost: $186.22
# concrete_cost: $6.00
# assembly_cost: $170.30
# generator_cost: $351.50
# rotor_cost: $88.72
# steel_component_cost: $110.18
# rotor_construction_cost: $25.00
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $143.34
# charge_controller_cost: $198.78
# gearbox_cost: $186.22
# concrete_cost: $6.00
# assembly_cost: $170.30
# generator_cost: $351.50
# rotor_cost: $88.72
# steel_component_cost: $110.18
# rotor_construction_cost: $25.00
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $143.34
# charge_controller_cost: $198.78
# gearbox_cost: $186.22
# concrete_cost: $6.00
# assembly_cost: $170.30
# generator_cost: $351.50
# rotor_cost: $503.43
# steel_component_cost: $273.04
# rotor_construction_cost: $214.85
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $206.54
# charge_controller_cost: $840.14
# gearbox_cost: $379.96
# concrete_cost: $26.75
# assembly_cost: $329.03
# generator_cost: $1145.13
# rotor_cost: $88.72
# steel_component_cost: $110.18
# rotor_construction_cost: $25.00
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $285.54
# charge_controller_cost: $1116.36
# gearbox_cost: $463.40
# concrete_cost: $52.98
# assembly_cost: $507.62
# generator_cost: $2038.10
# rotor_cost: $503.43
# steel_component_cost: $273.04
# rotor_construction_cost: $214.85
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $285.54
# charge_controller_cost: $1116.36
# gearbox_cost: $463.40
# concrete_cost: $52.98
# assembly_cost: $507.62
# generator_cost: $2038.10
# rotor_cost: $503.43
# steel_component_cost: $273.04
# rotor_construction_cost: $214.85
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $285.54
# charge_controller_cost: $1116.36
# gearbox_cost: $463.40
# concrete_cost: $52.98
# assembly_cost: $507.62
# generator_cost: $2038.10
# rotor_cost: $1752.86
# steel_component_cost: $663.05
# rotor_construction_cost: $582.83
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $285.54
# charge_controller_cost: $1116.36
# gearbox_cost: $463.40
# concrete_cost: $52.98
# assembly_cost: $507.62
# generator_cost: $2038.10
# rotor_cost: $88.72
# steel_component_cost: $110.18
# rotor_construction_cost: $25.00
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $143.34
# charge_controller_cost: $198.78
# gearbox_cost: $186.22
# concrete_cost: $6.00
# assembly_cost: $170.30
# generator_cost: $351.50
# rotor_cost: $88.72
# steel_component_cost: $110.18
# rotor_construction_cost: $25.00
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $285.54
# charge_controller_cost: $1116.36
# gearbox_cost: $463.40
# concrete_cost: $52.98
# assembly_cost: $507.62
# generator_cost: $2038.10
# rotor_cost: $503.43
# steel_component_cost: $273.04
# rotor_construction_cost: $214.85
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $285.54
# charge_controller_cost: $1116.36
# gearbox_cost: $463.40
# concrete_cost: $52.98
# assembly_cost: $507.62
# generator_cost: $2038.10
# rotor_cost: $88.72
# steel_component_cost: $110.18
# rotor_construction_cost: $25.00
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $443.54
# charge_controller_cost: $1392.58
# gearbox_cost: $546.83
# concrete_cost: $106.44
# assembly_cost: $798.77
# generator_cost: $3493.87
# rotor_cost: $1058.14
# steel_component_cost: $457.33
# rotor_construction_cost: $400.79
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $206.54
# charge_controller_cost: $840.14
# gearbox_cost: $379.96
# concrete_cost: $26.75
# assembly_cost: $329.03
# generator_cost: $1145.13
# rotor_cost: $503.43
# steel_component_cost: $273.04
# rotor_construction_cost: $214.85
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $443.54
# charge_controller_cost: $1392.58
# gearbox_cost: $546.83
# concrete_cost: $106.44
# assembly_cost: $798.77
# generator_cost: $3493.87
# rotor_cost: $1752.86
# steel_component_cost: $663.05
# rotor_construction_cost: $582.83
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $285.54
# charge_controller_cost: $1116.36
# gearbox_cost: $463.40
# concrete_cost: $52.98
# assembly_cost: $507.62
# generator_cost: $2038.10
# rotor_cost: $1058.14
# steel_component_cost: $457.33
# rotor_construction_cost: $400.79
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $206.54
# charge_controller_cost: $840.14
# gearbox_cost: $379.96
# concrete_cost: $26.75
# assembly_cost: $329.03
# generator_cost: $1145.13
# rotor_cost: $88.72
# steel_component_cost: $110.18
# rotor_construction_cost: $25.00
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $206.54
# charge_controller_cost: $840.14
# gearbox_cost: $379.96
# concrete_cost: $26.75
# assembly_cost: $329.03
# generator_cost: $1145.13
# rotor_cost: $1058.14
# steel_component_cost: $457.33
# rotor_construction_cost: $400.79
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $443.54
# charge_controller_cost: $1392.58
# gearbox_cost: $546.83
# concrete_cost: $106.44
# assembly_cost: $798.77
# generator_cost: $3493.87
# rotor_cost: $88.72
# steel_component_cost: $110.18
# rotor_construction_cost: $25.00
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $443.54
# charge_controller_cost: $1392.58
# gearbox_cost: $546.83
# concrete_cost: $106.44
# assembly_cost: $798.77
# generator_cost: $3493.87
# rotor_cost: $88.72
# steel_component_cost: $110.18
# rotor_construction_cost: $25.00
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $443.54
# charge_controller_cost: $1392.58
# gearbox_cost: $546.83
# concrete_cost: $106.44
# assembly_cost: $798.77
# generator_cost: $3493.87
# rotor_cost: $1058.14
# steel_component_cost: $457.33
# rotor_construction_cost: $400.79
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $285.54
# charge_controller_cost: $1116.36
# gearbox_cost: $463.40
# concrete_cost: $52.98
# assembly_cost: $507.62
# generator_cost: $2038.10
# rotor_cost: $1058.14
# steel_component_cost: $457.33
# rotor_construction_cost: $400.79
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $206.54
# charge_controller_cost: $840.14
# gearbox_cost: $379.96
# concrete_cost: $26.75
# assembly_cost: $329.03
# generator_cost: $1145.13
# rotor_cost: $88.72
# steel_component_cost: $110.18
# rotor_construction_cost: $25.00
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $443.54
# charge_controller_cost: $1392.58
# gearbox_cost: $546.83
# concrete_cost: $106.44
# assembly_cost: $798.77
# generator_cost: $3493.87
# rotor_cost: $503.43
# steel_component_cost: $273.04
# rotor_construction_cost: $214.85
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $443.54
# charge_controller_cost: $1392.58
# gearbox_cost: $546.83
# concrete_cost: $106.44
# assembly_cost: $798.77
# generator_cost: $3493.87
# rotor_cost: $1752.86
# steel_component_cost: $663.05
# rotor_construction_cost: $582.83
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $206.54
# charge_controller_cost: $840.14
# gearbox_cost: $379.96
# concrete_cost: $26.75
# assembly_cost: $329.03
# generator_cost: $1145.13
# rotor_cost: $503.43
# steel_component_cost: $273.04
# rotor_construction_cost: $214.85
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $443.54
# charge_controller_cost: $1392.58
# gearbox_cost: $546.83
# concrete_cost: $106.44
# assembly_cost: $798.77
# generator_cost: $3493.87
# rotor_cost: $503.43
# steel_component_cost: $273.04
# rotor_construction_cost: $214.85
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $413.08
# charge_controller_cost: $1680.28
# gearbox_cost: $759.92
# concrete_cost: $53.49
# assembly_cost: $658.05
# generator_cost: $2290.25
# rotor_cost: $1006.86
# steel_component_cost: $546.08
# rotor_construction_cost: $429.70
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $887.08
# charge_controller_cost: $2785.15
# gearbox_cost: $1093.67
# concrete_cost: $212.89
# assembly_cost: $1597.55
# generator_cost: $6987.73
# rotor_cost: $3505.72
# steel_component_cost: $1326.10
# rotor_construction_cost: $1165.66
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $887.08
# charge_controller_cost: $2785.15
# gearbox_cost: $1093.67
# concrete_cost: $212.89
# assembly_cost: $1597.55
# generator_cost: $6987.73
# rotor_cost: $1006.86
# steel_component_cost: $546.08
# rotor_construction_cost: $429.70
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $571.08
# charge_controller_cost: $2232.72
# gearbox_cost: $926.79
# concrete_cost: $105.96
# assembly_cost: $1015.24
# generator_cost: $4076.20
# rotor_cost: $2116.29
# steel_component_cost: $914.66
# rotor_construction_cost: $801.59
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $887.08
# charge_controller_cost: $2785.15
# gearbox_cost: $1093.67
# concrete_cost: $212.89
# assembly_cost: $1597.55
# generator_cost: $6987.73
# rotor_cost: $177.43
# steel_component_cost: $220.36
# rotor_construction_cost: $50.01
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $413.08
# charge_controller_cost: $1680.28
# gearbox_cost: $759.92
# concrete_cost: $53.49
# assembly_cost: $658.05
# generator_cost: $2290.25
# rotor_cost: $2116.29
# steel_component_cost: $914.66
# rotor_construction_cost: $801.59
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $413.08
# charge_controller_cost: $1680.28
# gearbox_cost: $759.92
# concrete_cost: $53.49
# assembly_cost: $658.05
# generator_cost: $2290.25
# rotor_cost: $177.43
# steel_component_cost: $220.36
# rotor_construction_cost: $50.01
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $887.08
# charge_controller_cost: $2785.15
# gearbox_cost: $1093.67
# concrete_cost: $212.89
# assembly_cost: $1597.55
# generator_cost: $6987.73
# rotor_cost: $177.43
# steel_component_cost: $220.36
# rotor_construction_cost: $50.01
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $413.08
# charge_controller_cost: $1680.28
# gearbox_cost: $759.92
# concrete_cost: $53.49
# assembly_cost: $658.05
# generator_cost: $2290.25
# rotor_cost: $1006.86
# steel_component_cost: $546.08
# rotor_construction_cost: $429.70
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $887.08
# charge_controller_cost: $2785.15
# gearbox_cost: $1093.67
# concrete_cost: $212.89
# assembly_cost: $1597.55
# generator_cost: $6987.73
# rotor_cost: $1006.86
# steel_component_cost: $546.08
# rotor_construction_cost: $429.70
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $887.08
# charge_controller_cost: $2785.15
# gearbox_cost: $1093.67
# concrete_cost: $212.89
# assembly_cost: $1597.55
# generator_cost: $6987.73
# rotor_cost: $2116.29
# steel_component_cost: $914.66
# rotor_construction_cost: $801.59
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $571.08
# charge_controller_cost: $2232.72
# gearbox_cost: $926.79
# concrete_cost: $105.96
# assembly_cost: $1015.24
# generator_cost: $4076.20
# rotor_cost: $177.43
# steel_component_cost: $220.36
# rotor_construction_cost: $50.01
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $571.08
# charge_controller_cost: $2232.72
# gearbox_cost: $926.79
# concrete_cost: $105.96
# assembly_cost: $1015.24
# generator_cost: $4076.20
# rotor_cost: $1006.86
# steel_component_cost: $546.08
# rotor_construction_cost: $429.70
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $286.68
# charge_controller_cost: $397.57
# gearbox_cost: $372.44
# concrete_cost: $12.00
# assembly_cost: $340.60
# generator_cost: $703.01
# rotor_cost: $1006.86
# steel_component_cost: $546.08
# rotor_construction_cost: $429.70
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $286.68
# charge_controller_cost: $397.57
# gearbox_cost: $372.44
# concrete_cost: $12.00
# assembly_cost: $340.60
# generator_cost: $703.01
# rotor_cost: $177.43
# steel_component_cost: $220.36
# rotor_construction_cost: $50.01
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $887.08
# charge_controller_cost: $2785.15
# gearbox_cost: $1093.67
# concrete_cost: $212.89
# assembly_cost: $1597.55
# generator_cost: $6987.73
# rotor_cost: $2116.29
# steel_component_cost: $914.66
# rotor_construction_cost: $801.59
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $571.08
# charge_controller_cost: $2232.72
# gearbox_cost: $926.79
# concrete_cost: $105.96
# assembly_cost: $1015.24
# generator_cost: $4076.20
# rotor_cost: $177.43
# steel_component_cost: $220.36
# rotor_construction_cost: $50.01
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $286.68
# charge_controller_cost: $397.57
# gearbox_cost: $372.44
# concrete_cost: $12.00
# assembly_cost: $340.60
# generator_cost: $703.01
# rotor_cost: $177.43
# steel_component_cost: $220.36
# rotor_construction_cost: $50.01
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $286.68
# charge_controller_cost: $397.57
# gearbox_cost: $372.44
# concrete_cost: $12.00
# assembly_cost: $340.60
# generator_cost: $703.01
# rotor_cost: $177.43
# steel_component_cost: $220.36
# rotor_construction_cost: $50.01
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $286.68
# charge_controller_cost: $397.57
# gearbox_cost: $372.44
# concrete_cost: $12.00
# assembly_cost: $340.60
# generator_cost: $703.01
# rotor_cost: $1006.86
# steel_component_cost: $546.08
# rotor_construction_cost: $429.70
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $413.08
# charge_controller_cost: $1680.28
# gearbox_cost: $759.92
# concrete_cost: $53.49
# assembly_cost: $658.05
# generator_cost: $2290.25
# rotor_cost: $177.43
# steel_component_cost: $220.36
# rotor_construction_cost: $50.01
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $571.08
# charge_controller_cost: $2232.72
# gearbox_cost: $926.79
# concrete_cost: $105.96
# assembly_cost: $1015.24
# generator_cost: $4076.20
# rotor_cost: $1006.86
# steel_component_cost: $546.08
# rotor_construction_cost: $429.70
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $571.08
# charge_controller_cost: $2232.72
# gearbox_cost: $926.79
# concrete_cost: $105.96
# assembly_cost: $1015.24
# generator_cost: $4076.20
# rotor_cost: $1006.86
# steel_component_cost: $546.08
# rotor_construction_cost: $429.70
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $571.08
# charge_controller_cost: $2232.72
# gearbox_cost: $926.79
# concrete_cost: $105.96
# assembly_cost: $1015.24
# generator_cost: $4076.20
# rotor_cost: $3505.72
# steel_component_cost: $1326.10
# rotor_construction_cost: $1165.66
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $571.08
# charge_controller_cost: $2232.72
# gearbox_cost: $926.79
# concrete_cost: $105.96
# assembly_cost: $1015.24
# generator_cost: $4076.20
# rotor_cost: $177.43
# steel_component_cost: $220.36
# rotor_construction_cost: $50.01
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $286.68
# charge_controller_cost: $397.57
# gearbox_cost: $372.44
# concrete_cost: $12.00
# assembly_cost: $340.60
# generator_cost: $703.01
# rotor_cost: $177.43
# steel_component_cost: $220.36
# rotor_construction_cost: $50.01
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $571.08
# charge_controller_cost: $2232.72
# gearbox_cost: $926.79
# concrete_cost: $105.96
# assembly_cost: $1015.24
# generator_cost: $4076.20
# rotor_cost: $1006.86
# steel_component_cost: $546.08
# rotor_construction_cost: $429.70
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $571.08
# charge_controller_cost: $2232.72
# gearbox_cost: $926.79
# concrete_cost: $105.96
# assembly_cost: $1015.24
# generator_cost: $4076.20
# rotor_cost: $177.43
# steel_component_cost: $220.36
# rotor_construction_cost: $50.01
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $887.08
# charge_controller_cost: $2785.15
# gearbox_cost: $1093.67
# concrete_cost: $212.89
# assembly_cost: $1597.55
# generator_cost: $6987.73
# rotor_cost: $2116.29
# steel_component_cost: $914.66
# rotor_construction_cost: $801.59
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $413.08
# charge_controller_cost: $1680.28
# gearbox_cost: $759.92
# concrete_cost: $53.49
# assembly_cost: $658.05
# generator_cost: $2290.25
# rotor_cost: $1006.86
# steel_component_cost: $546.08
# rotor_construction_cost: $429.70
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $887.08
# charge_controller_cost: $2785.15
# gearbox_cost: $1093.67
# concrete_cost: $212.89
# assembly_cost: $1597.55
# generator_cost: $6987.73
# rotor_cost: $3505.72
# steel_component_cost: $1326.10
# rotor_construction_cost: $1165.66
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $571.08
# charge_controller_cost: $2232.72
# gearbox_cost: $926.79
# concrete_cost: $105.96
# assembly_cost: $1015.24
# generator_cost: $4076.20
# rotor_cost: $2116.29
# steel_component_cost: $914.66
# rotor_construction_cost: $801.59
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $413.08
# charge_controller_cost: $1680.28
# gearbox_cost: $759.92
# concrete_cost: $53.49
# assembly_cost: $658.05
# generator_cost: $2290.25
# rotor_cost: $177.43
# steel_component_cost: $220.36
# rotor_construction_cost: $50.01
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $413.08
# charge_controller_cost: $1680.28
# gearbox_cost: $759.92
# concrete_cost: $53.49
# assembly_cost: $658.05
# generator_cost: $2290.25
# rotor_cost: $2116.29
# steel_component_cost: $914.66
# rotor_construction_cost: $801.59
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $887.08
# charge_controller_cost: $2785.15
# gearbox_cost: $1093.67
# concrete_cost: $212.89
# assembly_cost: $1597.55
# generator_cost: $6987.73
# rotor_cost: $177.43
# steel_component_cost: $220.36
# rotor_construction_cost: $50.01
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $887.08
# charge_controller_cost: $2785.15
# gearbox_cost: $1093.67
# concrete_cost: $212.89
# assembly_cost: $1597.55
# generator_cost: $6987.73
# rotor_cost: $177.43
# steel_component_cost: $220.36
# rotor_construction_cost: $50.01
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $887.08
# charge_controller_cost: $2785.15
# gearbox_cost: $1093.67
# concrete_cost: $212.89
# assembly_cost: $1597.55
# generator_cost: $6987.73
# rotor_cost: $2116.29
# steel_component_cost: $914.66
# rotor_construction_cost: $801.59
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $571.08
# charge_controller_cost: $2232.72
# gearbox_cost: $926.79
# concrete_cost: $105.96
# assembly_cost: $1015.24
# generator_cost: $4076.20
# rotor_cost: $2116.29
# steel_component_cost: $914.66
# rotor_construction_cost: $801.59
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $413.08
# charge_controller_cost: $1680.28
# gearbox_cost: $759.92
# concrete_cost: $53.49
# assembly_cost: $658.05
# generator_cost: $2290.25
# rotor_cost: $177.43
# steel_component_cost: $220.36
# rotor_construction_cost: $50.01
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $887.08
# charge_controller_cost: $2785.15
# gearbox_cost: $1093.67
# concrete_cost: $212.89
# assembly_cost: $1597.55
# generator_cost: $6987.73
# rotor_cost: $1006.86
# steel_component_cost: $546.08
# rotor_construction_cost: $429.70
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $887.08
# charge_controller_cost: $2785.15
# gearbox_cost: $1093.67
# concrete_cost: $212.89
# assembly_cost: $1597.55
# generator_cost: $6987.73
# rotor_cost: $3505.72
# steel_component_cost: $1326.10
# rotor_construction_cost: $1165.66
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $413.08
# charge_controller_cost: $1680.28
# gearbox_cost: $759.92
# concrete_cost: $53.49
# assembly_cost: $658.05
# generator_cost: $2290.25
# rotor_cost: $1006.86
# steel_component_cost: $546.08
# rotor_construction_cost: $429.70
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $887.08
# charge_controller_cost: $2785.15
# gearbox_cost: $1093.67
# concrete_cost: $212.89
# assembly_cost: $1597.55
# generator_cost: $6987.73
# rotor_cost: $1006.86
# steel_component_cost: $546.08
# rotor_construction_cost: $429.70
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $826.16
# charge_controller_cost: $3360.56
# gearbox_cost: $1519.83
# concrete_cost: $106.98
# assembly_cost: $1316.10
# generator_cost: $4580.51
# rotor_cost: $2013.72
# steel_component_cost: $1092.16
# rotor_construction_cost: $859.40
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $1774.16
# charge_controller_cost: $5570.31
# gearbox_cost: $2187.34
# concrete_cost: $425.77
# assembly_cost: $3195.09
# generator_cost: $13975.47
# rotor_cost: $2013.72
# steel_component_cost: $1092.16
# rotor_construction_cost: $859.40
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $1774.16
# charge_controller_cost: $5570.31
# gearbox_cost: $2187.34
# concrete_cost: $425.77
# assembly_cost: $3195.09
# generator_cost: $13975.47
# rotor_cost: $354.86
# steel_component_cost: $440.72
# rotor_construction_cost: $100.01
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $826.16
# charge_controller_cost: $3360.56
# gearbox_cost: $1519.83
# concrete_cost: $106.98
# assembly_cost: $1316.10
# generator_cost: $4580.51
# rotor_cost: $4232.58
# steel_component_cost: $1829.32
# rotor_construction_cost: $1603.17
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $826.16
# charge_controller_cost: $3360.56
# gearbox_cost: $1519.83
# concrete_cost: $106.98
# assembly_cost: $1316.10
# generator_cost: $4580.51
# rotor_cost: $354.86
# steel_component_cost: $440.72
# rotor_construction_cost: $100.01
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $1774.16
# charge_controller_cost: $5570.31
# gearbox_cost: $2187.34
# concrete_cost: $425.77
# assembly_cost: $3195.09
# generator_cost: $13975.47
# rotor_cost: $354.86
# steel_component_cost: $440.72
# rotor_construction_cost: $100.01
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $826.16
# charge_controller_cost: $3360.56
# gearbox_cost: $1519.83
# concrete_cost: $106.98
# assembly_cost: $1316.10
# generator_cost: $4580.51
# rotor_cost: $2013.72
# steel_component_cost: $1092.16
# rotor_construction_cost: $859.40
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $1774.16
# charge_controller_cost: $5570.31
# gearbox_cost: $2187.34
# concrete_cost: $425.77
# assembly_cost: $3195.09
# generator_cost: $13975.47
# rotor_cost: $2013.72
# steel_component_cost: $1092.16
# rotor_construction_cost: $859.40
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $1142.16
# charge_controller_cost: $4465.43
# gearbox_cost: $1853.59
# concrete_cost: $211.92
# assembly_cost: $2030.48
# generator_cost: $8152.41
# rotor_cost: $354.86
# steel_component_cost: $440.72
# rotor_construction_cost: $100.01
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $1142.16
# charge_controller_cost: $4465.43
# gearbox_cost: $1853.59
# concrete_cost: $211.92
# assembly_cost: $2030.48
# generator_cost: $8152.41
# rotor_cost: $2013.72
# steel_component_cost: $1092.16
# rotor_construction_cost: $859.40
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $573.36
# charge_controller_cost: $795.13
# gearbox_cost: $744.88
# concrete_cost: $24.00
# assembly_cost: $681.20
# generator_cost: $1406.01
# rotor_cost: $2013.72
# steel_component_cost: $1092.16
# rotor_construction_cost: $859.40
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $573.36
# charge_controller_cost: $795.13
# gearbox_cost: $744.88
# concrete_cost: $24.00
# assembly_cost: $681.20
# generator_cost: $1406.01
# rotor_cost: $354.86
# steel_component_cost: $440.72
# rotor_construction_cost: $100.01
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $1142.16
# charge_controller_cost: $4465.43
# gearbox_cost: $1853.59
# concrete_cost: $211.92
# assembly_cost: $2030.48
# generator_cost: $8152.41
# rotor_cost: $354.86
# steel_component_cost: $440.72
# rotor_construction_cost: $100.01
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $573.36
# charge_controller_cost: $795.13
# gearbox_cost: $744.88
# concrete_cost: $24.00
# assembly_cost: $681.20
# generator_cost: $1406.01
# rotor_cost: $354.86
# steel_component_cost: $440.72
# rotor_construction_cost: $100.01
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $573.36
# charge_controller_cost: $795.13
# gearbox_cost: $744.88
# concrete_cost: $24.00
# assembly_cost: $681.20
# generator_cost: $1406.01
# rotor_cost: $354.86
# steel_component_cost: $440.72
# rotor_construction_cost: $100.01
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $573.36
# charge_controller_cost: $795.13
# gearbox_cost: $744.88
# concrete_cost: $24.00
# assembly_cost: $681.20
# generator_cost: $1406.01
# rotor_cost: $2013.72
# steel_component_cost: $1092.16
# rotor_construction_cost: $859.40
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $826.16
# charge_controller_cost: $3360.56
# gearbox_cost: $1519.83
# concrete_cost: $106.98
# assembly_cost: $1316.10
# generator_cost: $4580.51
# rotor_cost: $354.86
# steel_component_cost: $440.72
# rotor_construction_cost: $100.01
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $1142.16
# charge_controller_cost: $4465.43
# gearbox_cost: $1853.59
# concrete_cost: $211.92
# assembly_cost: $2030.48
# generator_cost: $8152.41
# rotor_cost: $2013.72
# steel_component_cost: $1092.16
# rotor_construction_cost: $859.40
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $1142.16
# charge_controller_cost: $4465.43
# gearbox_cost: $1853.59
# concrete_cost: $211.92
# assembly_cost: $2030.48
# generator_cost: $8152.41
# rotor_cost: $2013.72
# steel_component_cost: $1092.16
# rotor_construction_cost: $859.40
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $1142.16
# charge_controller_cost: $4465.43
# gearbox_cost: $1853.59
# concrete_cost: $211.92
# assembly_cost: $2030.48
# generator_cost: $8152.41
# rotor_cost: $354.86
# steel_component_cost: $440.72
# rotor_construction_cost: $100.01
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $573.36
# charge_controller_cost: $795.13
# gearbox_cost: $744.88
# concrete_cost: $24.00
# assembly_cost: $681.20
# generator_cost: $1406.01
# rotor_cost: $354.86
# steel_component_cost: $440.72
# rotor_construction_cost: $100.01
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $1142.16
# charge_controller_cost: $4465.43
# gearbox_cost: $1853.59
# concrete_cost: $211.92
# assembly_cost: $2030.48
# generator_cost: $8152.41
# rotor_cost: $2013.72
# steel_component_cost: $1092.16
# rotor_construction_cost: $859.40
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $1142.16
# charge_controller_cost: $4465.43
# gearbox_cost: $1853.59
# concrete_cost: $211.92
# assembly_cost: $2030.48
# generator_cost: $8152.41
# rotor_cost: $354.86
# steel_component_cost: $440.72
# rotor_construction_cost: $100.01
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $826.16
# charge_controller_cost: $3360.56
# gearbox_cost: $1519.83
# concrete_cost: $106.98
# assembly_cost: $1316.10
# generator_cost: $4580.51
# rotor_cost: $2013.72
# steel_component_cost: $1092.16
# rotor_construction_cost: $859.40
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $1142.16
# charge_controller_cost: $4465.43
# gearbox_cost: $1853.59
# concrete_cost: $211.92
# assembly_cost: $2030.48
# generator_cost: $8152.41
# rotor_cost: $4232.58
# steel_component_cost: $1829.32
# rotor_construction_cost: $1603.17
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $826.16
# charge_controller_cost: $3360.56
# gearbox_cost: $1519.83
# concrete_cost: $106.98
# assembly_cost: $1316.10
# generator_cost: $4580.51
# rotor_cost: $354.86
# steel_component_cost: $440.72
# rotor_construction_cost: $100.01
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $826.16
# charge_controller_cost: $3360.56
# gearbox_cost: $1519.83
# concrete_cost: $106.98
# assembly_cost: $1316.10
# generator_cost: $4580.51
# rotor_cost: $4232.58
# steel_component_cost: $1829.32
# rotor_construction_cost: $1603.17
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $1774.16
# charge_controller_cost: $5570.31
# gearbox_cost: $2187.34
# concrete_cost: $425.77
# assembly_cost: $3195.09
# generator_cost: $13975.47
# rotor_cost: $354.86
# steel_component_cost: $440.72
# rotor_construction_cost: $100.01
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $1774.16
# charge_controller_cost: $5570.31
# gearbox_cost: $2187.34
# concrete_cost: $425.77
# assembly_cost: $3195.09
# generator_cost: $13975.47
# rotor_cost: $354.86
# steel_component_cost: $440.72
# rotor_construction_cost: $100.01
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $1774.16
# charge_controller_cost: $5570.31
# gearbox_cost: $2187.34
# concrete_cost: $425.77
# assembly_cost: $3195.09
# generator_cost: $13975.47
# rotor_cost: $4232.58
# steel_component_cost: $1829.32
# rotor_construction_cost: $1603.17
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $1142.16
# charge_controller_cost: $4465.43
# gearbox_cost: $1853.59
# concrete_cost: $211.92
# assembly_cost: $2030.48
# generator_cost: $8152.41
# rotor_cost: $4232.58
# steel_component_cost: $1829.32
# rotor_construction_cost: $1603.17
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $826.16
# charge_controller_cost: $3360.56
# gearbox_cost: $1519.83
# concrete_cost: $106.98
# assembly_cost: $1316.10
# generator_cost: $4580.51
# rotor_cost: $354.86
# steel_component_cost: $440.72
# rotor_construction_cost: $100.01
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $1774.16
# charge_controller_cost: $5570.31
# gearbox_cost: $2187.34
# concrete_cost: $425.77
# assembly_cost: $3195.09
# generator_cost: $13975.47
# rotor_cost: $2013.72
# steel_component_cost: $1092.16
# rotor_construction_cost: $859.40
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $826.16
# charge_controller_cost: $3360.56
# gearbox_cost: $1519.83
# concrete_cost: $106.98
# assembly_cost: $1316.10
# generator_cost: $4580.51
# rotor_cost: $2013.72
# steel_component_cost: $1092.16
# rotor_construction_cost: $859.40
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $1774.16
# charge_controller_cost: $5570.31
# gearbox_cost: $2187.34
# concrete_cost: $425.77
# assembly_cost: $3195.09
# generator_cost: $13975.47
# rotor_cost: $2013.72
# steel_component_cost: $1092.16
# rotor_construction_cost: $859.40
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $1239.24
# charge_controller_cost: $5040.84
# gearbox_cost: $2279.75
# concrete_cost: $160.48
# assembly_cost: $1974.15
# generator_cost: $6870.76
# rotor_cost: $3020.58
# steel_component_cost: $1638.24
# rotor_construction_cost: $1289.10
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $2661.24
# charge_controller_cost: $8355.46
# gearbox_cost: $3281.01
# concrete_cost: $638.66
# assembly_cost: $4792.64
# generator_cost: $20963.20
# rotor_cost: $532.29
# steel_component_cost: $661.08
# rotor_construction_cost: $150.02
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $1239.24
# charge_controller_cost: $5040.84
# gearbox_cost: $2279.75
# concrete_cost: $160.48
# assembly_cost: $1974.15
# generator_cost: $6870.76
# rotor_cost: $532.29
# steel_component_cost: $661.08
# rotor_construction_cost: $150.02
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $2661.24
# charge_controller_cost: $8355.46
# gearbox_cost: $3281.01
# concrete_cost: $638.66
# assembly_cost: $4792.64
# generator_cost: $20963.20
# rotor_cost: $532.29
# steel_component_cost: $661.08
# rotor_construction_cost: $150.02
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $1239.24
# charge_controller_cost: $5040.84
# gearbox_cost: $2279.75
# concrete_cost: $160.48
# assembly_cost: $1974.15
# generator_cost: $6870.76
# rotor_cost: $3020.58
# steel_component_cost: $1638.24
# rotor_construction_cost: $1289.10
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $2661.24
# charge_controller_cost: $8355.46
# gearbox_cost: $3281.01
# concrete_cost: $638.66
# assembly_cost: $4792.64
# generator_cost: $20963.20
# rotor_cost: $3020.58
# steel_component_cost: $1638.24
# rotor_construction_cost: $1289.10
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $1713.24
# charge_controller_cost: $6698.15
# gearbox_cost: $2780.38
# concrete_cost: $317.87
# assembly_cost: $3045.72
# generator_cost: $12228.61
# rotor_cost: $532.29
# steel_component_cost: $661.08
# rotor_construction_cost: $150.02
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $1713.24
# charge_controller_cost: $6698.15
# gearbox_cost: $2780.38
# concrete_cost: $317.87
# assembly_cost: $3045.72
# generator_cost: $12228.61
# rotor_cost: $3020.58
# steel_component_cost: $1638.24
# rotor_construction_cost: $1289.10
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $860.04
# charge_controller_cost: $1192.70
# gearbox_cost: $1117.32
# concrete_cost: $36.00
# assembly_cost: $1021.80
# generator_cost: $2109.02
# rotor_cost: $3020.58
# steel_component_cost: $1638.24
# rotor_construction_cost: $1289.10
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $860.04
# charge_controller_cost: $1192.70
# gearbox_cost: $1117.32
# concrete_cost: $36.00
# assembly_cost: $1021.80
# generator_cost: $2109.02
# rotor_cost: $532.29
# steel_component_cost: $661.08
# rotor_construction_cost: $150.02
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $1713.24
# charge_controller_cost: $6698.15
# gearbox_cost: $2780.38
# concrete_cost: $317.87
# assembly_cost: $3045.72
# generator_cost: $12228.61
# rotor_cost: $532.29
# steel_component_cost: $661.08
# rotor_construction_cost: $150.02
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $860.04
# charge_controller_cost: $1192.70
# gearbox_cost: $1117.32
# concrete_cost: $36.00
# assembly_cost: $1021.80
# generator_cost: $2109.02
# rotor_cost: $532.29
# steel_component_cost: $661.08
# rotor_construction_cost: $150.02
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $860.04
# charge_controller_cost: $1192.70
# gearbox_cost: $1117.32
# concrete_cost: $36.00
# assembly_cost: $1021.80
# generator_cost: $2109.02
# rotor_cost: $532.29
# steel_component_cost: $661.08
# rotor_construction_cost: $150.02
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $860.04
# charge_controller_cost: $1192.70
# gearbox_cost: $1117.32
# concrete_cost: $36.00
# assembly_cost: $1021.80
# generator_cost: $2109.02
# rotor_cost: $3020.58
# steel_component_cost: $1638.24
# rotor_construction_cost: $1289.10
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $1239.24
# charge_controller_cost: $5040.84
# gearbox_cost: $2279.75
# concrete_cost: $160.48
# assembly_cost: $1974.15
# generator_cost: $6870.76
# rotor_cost: $532.29
# steel_component_cost: $661.08
# rotor_construction_cost: $150.02
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $1713.24
# charge_controller_cost: $6698.15
# gearbox_cost: $2780.38
# concrete_cost: $317.87
# assembly_cost: $3045.72
# generator_cost: $12228.61
# rotor_cost: $3020.58
# steel_component_cost: $1638.24
# rotor_construction_cost: $1289.10
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $1713.24
# charge_controller_cost: $6698.15
# gearbox_cost: $2780.38
# concrete_cost: $317.87
# assembly_cost: $3045.72
# generator_cost: $12228.61
# rotor_cost: $3020.58
# steel_component_cost: $1638.24
# rotor_construction_cost: $1289.10
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $1713.24
# charge_controller_cost: $6698.15
# gearbox_cost: $2780.38
# ...
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $1652.32
# charge_controller_cost: $6721.13
# gearbox_cost: $3039.66
# concrete_cost: $213.97
# assembly_cost: $2632.20
# generator_cost: $9161.01
# rotor_cost: $4027.44
# steel_component_cost: $2184.32
# rotor_construction_cost: $1718.80
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $3548.32
# charge_controller_cost: $11140.61
# gearbox_cost: $4374.68
# concrete_cost: $851.54
# assembly_cost: $6390.19
# generator_cost: $27950.94
# rotor_cost: $4027.44
# steel_component_cost: $2184.32
# rotor_construction_cost: $1718.80
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $2065.40
# charge_controller_cost: $8401.41
# gearbox_cost: $3799.58
# concrete_cost: $267.46
# assembly_cost: $3290.25
# generator_cost: $11451.27
# rotor_cost: $5034.30
# steel_component_cost: $2730.40
# rotor_construction_cost: $2148.50
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $4435.40
# charge_controller_cost: $13925.76
# gearbox_cost: $5468.35
# concrete_cost: $1064.43
# assembly_cost: $7987.73
# generator_cost: $34938.67
# rotor_cost: $887.15
# steel_component_cost: $1101.80
# rotor_construction_cost: $250.03
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $2065.40
# charge_controller_cost: $8401.41
# gearbox_cost: $3799.58
# concrete_cost: $267.46
# assembly_cost: $3290.25
# generator_cost: $11451.27
# rotor_cost: $887.15
# steel_component_cost: $1101.80
# rotor_construction_cost: $250.03
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $4435.40
# charge_controller_cost: $13925.76
# gearbox_cost: $5468.35
# concrete_cost: $1064.43
# assembly_cost: $7987.73
# generator_cost: $34938.67
# rotor_cost: $887.15
# steel_component_cost: $1101.80
# rotor_construction_cost: $250.03
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $2855.40
# charge_controller_cost: $11163.59
# gearbox_cost: $4633.96
# concrete_cost: $529.79
# assembly_cost: $5076.20
# generator_cost: $20381.01
# rotor_cost: $887.15
# steel_component_cost: $1101.80
# rotor_construction_cost: $250.03
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $1433.40
# charge_controller_cost: $1987.83
# gearbox_cost: $1862.20
# concrete_cost: $59.99
# assembly_cost: $1703.01
# generator_cost: $3515.03
# rotor_cost: $5034.30
# steel_component_cost: $2730.40
# rotor_construction_cost: $2148.50
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $1433.40
# charge_controller_cost: $1987.83
# gearbox_cost: $1862.20
# concrete_cost: $59.99
# assembly_cost: $1703.01
# generator_cost: $3515.03
# rotor_cost: $887.15
# steel_component_cost: $1101.80
# rotor_construction_cost: $250.03
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $2855.40
# charge_controller_cost: $11163.59
# gearbox_cost: $4633.96
# concrete_cost: $529.79
# assembly_cost: $5076.20
# generator_cost: $20381.01
# rotor_cost: $887.15
# steel_component_cost: $1101.80
# rotor_construction_cost: $250.03
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $1433.40
# charge_controller_cost: $1987.83
# gearbox_cost: $1862.20
# concrete_cost: $59.99
# assembly_cost: $1703.01
# generator_cost: $3515.03
# rotor_cost: $887.15
# steel_component_cost: $1101.80
# rotor_construction_cost: $250.03
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $1433.40
# charge_controller_cost: $1987.83
# gearbox_cost: $1862.20
# concrete_cost: $59.99
# assembly_cost: $1703.01
# generator_cost: $3515.03
# rotor_cost: $887.15
# steel_component_cost: $1101.80
# rotor_construction_cost: $250.03
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $1433.40
# charge_controller_cost: $1987.83
# gearbox_cost: $1862.20
# concrete_cost: $59.99
# assembly_cost: $1703.01
# generator_cost: $3515.03
# rotor_cost: $5034.30
# steel_component_cost: $2730.40
# rotor_construction_cost: $2148.50
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $2065.40
# charge_controller_cost: $8401.41
# gearbox_cost: $3799.58
# concrete_cost: $267.46
# assembly_cost: $3290.25
# generator_cost: $11451.27
# rotor_cost: $887.15
# steel_component_cost: $1101.80
# rotor_construction_cost: $250.03
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $2855.40
# charge_controller_cost: $11163.59
# gearbox_cost: $4633.96
# concrete_cost: $529.79
# assembly_cost: $5076.20
# generator_cost: $20381.01
# rotor_cost: $887.15
# steel_component_cost: $1101.80
# rotor_construction_cost: $250.03
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $1433.40
# charge_controller_cost: $1987.83
# gearbox_cost: $1862.20
# concrete_cost: $59.99
# assembly_cost: $1703.01
# generator_cost: $3515.03
# rotor_cost: $887.15
# steel_component_cost: $1101.80
# rotor_construction_cost: $250.03
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $2855.40
# charge_controller_cost: $11163.59
# gearbox_cost: $4633.96
# concrete_cost: $529.79
# assembly_cost: $5076.20
# generator_cost: $20381.01
# rotor_cost: $5034.30
# steel_component_cost: $2730.40
# rotor_construction_cost: $2148.50
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $2855.40
# charge_controller_cost: $11163.59
# gearbox_cost: $4633.96
# concrete_cost: $529.79
# assembly_cost: $5076.20
# generator_cost: $20381.01
# rotor_cost: $887.15
# steel_component_cost: $1101.80
# rotor_construction_cost: $250.03
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $2065.40
# charge_controller_cost: $8401.41
# gearbox_cost: $3799.58
# concrete_cost: $267.46
# assembly_cost: $3290.25
# generator_cost: $11451.27
# rotor_cost: $887.15
# steel_component_cost: $1101.80
# rotor_construction_cost: $250.03
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $4435.40
# charge_controller_cost: $13925.76
# gearbox_cost: $5468.35
# concrete_cost: $1064.43
# assembly_cost: $7987.73
# generator_cost: $34938.67
# rotor_cost: $887.15
# steel_component_cost: $1101.80
# rotor_construction_cost: $250.03
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $4435.40
# charge_controller_cost: $13925.76
# gearbox_cost: $5468.35
# concrete_cost: $1064.43
# assembly_cost: $7987.73
# generator_cost: $34938.67
# rotor_cost: $887.15
# steel_component_cost: $1101.80
# rotor_construction_cost: $250.03
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $2065.40
# charge_controller_cost: $8401.41
# gearbox_cost: $3799.58
# concrete_cost: $267.46
# assembly_cost: $3290.25
# generator_cost: $11451.27
# rotor_cost: $887.15
# steel_component_cost: $1101.80
# rotor_construction_cost: $250.03
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $2065.40
# charge_controller_cost: $8401.41
# gearbox_cost: $3799.58
# concrete_cost: $267.46
# assembly_cost: $3290.25
# generator_cost: $11451.27
# rotor_cost: $5034.30
# steel_component_cost: $2730.40
# rotor_construction_cost: $2148.50
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $5322.48
# charge_controller_cost: $16710.92
# gearbox_cost: $6562.02
# concrete_cost: $1277.32
# assembly_cost: $9585.28
# generator_cost: $41926.41
# rotor_cost: $1064.58
# steel_component_cost: $1322.16
# rotor_construction_cost: $300.03
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $2478.48
# charge_controller_cost: $10081.69
# gearbox_cost: $4559.50
# concrete_cost: $320.95
# assembly_cost: $3948.30
# generator_cost: $13741.52
# rotor_cost: $1064.58
# steel_component_cost: $1322.16
# rotor_construction_cost: $300.03
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $5322.48
# charge_controller_cost: $16710.92
# gearbox_cost: $6562.02
# concrete_cost: $1277.32
# assembly_cost: $9585.28
# generator_cost: $41926.41
# rotor_cost: $1064.58
# steel_component_cost: $1322.16
# rotor_construction_cost: $300.03
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $3426.48
# charge_controller_cost: $13396.30
# gearbox_cost: $5560.76
# concrete_cost: $635.75
# assembly_cost: $6091.44
# generator_cost: $24457.22
# rotor_cost: $1064.58
# steel_component_cost: $1322.16
# rotor_construction_cost: $300.03
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $1720.08
# charge_controller_cost: $2385.39
# gearbox_cost: $2234.64
# concrete_cost: $71.99
# assembly_cost: $2043.61
# generator_cost: $4218.03
# rotor_cost: $1064.58
# steel_component_cost: $1322.16
# rotor_construction_cost: $300.03
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $3426.48
# charge_controller_cost: $13396.30
# gearbox_cost: $5560.76
# concrete_cost: $635.75
# assembly_cost: $6091.44
# generator_cost: $24457.22
# rotor_cost: $1064.58
# steel_component_cost: $1322.16
# rotor_construction_cost: $300.03
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $1720.08
# charge_controller_cost: $2385.39
# gearbox_cost: $2234.64
# concrete_cost: $71.99
# assembly_cost: $2043.61
# generator_cost: $4218.03
# rotor_cost: $1064.58
# steel_component_cost: $1322.16
# rotor_construction_cost: $300.03
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $1720.08
# charge_controller_cost: $2385.39
# gearbox_cost: $2234.64
# concrete_cost: $71.99
# assembly_cost: $2043.61
# generator_cost: $4218.03
# rotor_cost: $1064.58
# steel_component_cost: $1322.16
# rotor_construction_cost: $300.03
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $2478.48
# charge_controller_cost: $10081.69
# gearbox_cost: $4559.50
# concrete_cost: $320.95
# assembly_cost: $3948.30
# generator_cost: $13741.52
# rotor_cost: $1064.58
# steel_component_cost: $1322.16
# rotor_construction_cost: $300.03
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $3426.48
# charge_controller_cost: $13396.30
# gearbox_cost: $5560.76
# concrete_cost: $635.75
# assembly_cost: $6091.44
# generator_cost: $24457.22
# rotor_cost: $1064.58
# steel_component_cost: $1322.16
# rotor_construction_cost: $300.03
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $1720.08
# charge_controller_cost: $2385.39
# gearbox_cost: $2234.64
# concrete_cost: $71.99
# assembly_cost: $2043.61
# generator_cost: $4218.03
# rotor_cost: $1064.58
# steel_component_cost: $1322.16
# rotor_construction_cost: $300.03
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $3426.48
# charge_controller_cost: $13396.30
# gearbox_cost: $5560.76
# concrete_cost: $635.75
# assembly_cost: $6091.44
# generator_cost: $24457.22
# rotor_cost: $1064.58
# steel_component_cost: $1322.16
# rotor_construction_cost: $300.03
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $2478.48
# charge_controller_cost: $10081.69
# gearbox_cost: $4559.50
# concrete_cost: $320.95
# assembly_cost: $3948.30
# generator_cost: $13741.52
# rotor_cost: $1064.58
# steel_component_cost: $1322.16
# rotor_construction_cost: $300.03
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $5322.48
# charge_controller_cost: $16710.92
# gearbox_cost: $6562.02
# concrete_cost: $1277.32
# assembly_cost: $9585.28
# generator_cost: $41926.41
# rotor_cost: $1064.58
# steel_component_cost: $1322.16
# rotor_construction_cost: $300.03
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# Individual CAPEX components:
# anchor_cost: $2478.48
# charge_controller_cost: $10081.69
# gearbox_cost: $4559.50
# concrete_cost: $320.95
# assembly_cost: $3948.30
# generator_cost: $13741.52
# rotor_cost: $1064.58
# steel_component_cost: $1322.16
# rotor_construction_cost: $300.03
# battery_cost: $3000.00
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()
# USING user_defined_pitch_constraint()

# %%
# Display the DataFrame
print(results_df)
# Out:
#      radius   prated  dcable   dHub_min        lcoe  number_of_turbines  \
# 0       1.0   5000.0     6.0   1.359212   66.934227                   1
# 1       2.0  20000.0    18.0   3.947978    6.519327                   1
# 2       1.0  20000.0    14.0   8.570084   26.589119                   1
# 3       1.5  10000.0    18.0   3.672485   15.337525                   1
# 4       0.5  20000.0    14.0  12.995591  125.062823                   1
# ..      ...      ...     ...        ...         ...                 ...
# 205     0.5   1000.0    10.0   1.619426   12.346494                  12
# 206     0.5  10000.0    14.0  10.994630   11.038388                  12
# 207     0.5   5000.0    14.0   7.670730   10.740745                  12
# 208     0.5  20000.0     6.0   5.569539   11.487441                  12
# 209     0.5   5000.0    10.0   5.479093   10.740745                  12
#
#      annual_energy  capacity_factor  num_batteries_charged  \
# 0      2566.571421         0.058598                      4
# 1     10500.289237         0.059933                     20
# 2      2566.571421         0.014649                      4
# 3      5893.008830         0.067272                     11
# 4       545.020858         0.003111                      1
# ..             ...              ...                    ...
# 205    6540.250298         0.746604                     12
# 206    6540.250298         0.074660                     12
# 207    6540.250298         0.149321                     12
# 208    6540.250298         0.037330                     12
# 209    6540.250298         0.149321                     12
#
#      charge_time_average  anchor_cost  charge_controller_cost  gearbox_cost  \
# 0              73.074306       206.54              840.140662    379.958124
# 1              16.566528       443.54             1392.576478    546.834752
# 2              73.074306       443.54             1392.576478    546.834752
# 3              29.893687       285.54             1116.358570    463.396438
# 4             324.202778       443.54             1392.576478    546.834752
# ..                   ...          ...                     ...           ...
# 205            27.016898      1720.08             2385.390479   2234.644296
# 206            27.016898      3426.48            13396.302840   5560.757253
# 207            27.016898      2478.48            10081.687940   4559.497484
# 208            27.016898      5322.48            16710.917740   6562.017022
# 209            27.016898      2478.48            10081.687940   4559.497484
#
#      concrete_cost  assembly_cost  generator_cost  rotor_cost  \
# 0        26.746122     329.025327     1145.126633     503.430
# 1       106.443053     798.773426     3493.867133    1752.860
# 2       106.443053     798.773426     3493.867133     503.430
# 3        52.979159     507.620277     2038.101387    1058.145
# 4       106.443053     798.773426     3493.867133      88.715
# ..             ...            ...             ...         ...
# 205      71.990034    2043.606554     4218.032723    1064.580
# 206     635.749912    6091.443325    24457.216644    1064.580
# 207     320.953468    3948.303921    13741.519596    1064.580
# 208    1277.316638    9585.281117    41926.405596    1064.580
# 209     320.953468    3948.303921    13741.519596    1064.580
#
#      steel_component_cost  rotor_construction_cost  battery_cost
# 0                  273.04                 214.8500        3000.0
# 1                  663.05                 582.8300        3000.0
# 2                  273.04                 214.8500        3000.0
# 3                  457.33                 400.7925        3000.0
# 4                  110.18                  25.0025        3000.0
# ..                    ...                      ...           ...
# 205               1322.16                 300.0300        3000.0
# 206               1322.16                 300.0300        3000.0
# 207               1322.16                 300.0300        3000.0
# 208               1322.16                 300.0300        3000.0
# 209               1322.16                 300.0300        3000.0
#
# [210 rows x 20 columns]

# %%
# Extract the optimal values
min_lcoe = results_df.loc[results_df['lcoe'].idxmin()]
opt_radius = min_lcoe['radius']
opt_prated = min_lcoe['prated']
opt_dcable = min_lcoe['dcable']
opt_number_of_turbines = min_lcoe['number_of_turbines']

# Function to plot heatmap with title
def plot_heatmap(x_range, y_range, values, x_label, y_label, ax, title):
    # Create a custom colormap from the 'bone' colormap, excluding the lightest part
    bone_cmap = plt.get_cmap('bone')
    custom_bone_cmap = mcolors.LinearSegmentedColormap.from_list(
        'custom_bone', bone_cmap(np.linspace(0, 0.8, 256))
    )
    sns.heatmap(values, xticklabels=np.round(x_range, 2), yticklabels=np.round(y_range, 2), cmap=custom_bone_cmap, annot=True, ax=ax)
    ax.set_xlabel(x_label)
    ax.set_ylabel(y_label)
    ax.set_title(f'{title} Heatmap ({x_label} vs {y_label})')

# Create subplots for the six heatmaps
fig, axs = plt.subplots(1, 6, figsize=(36, 8))

# Heatmap with x and y axis as radius and prated
subset_df = results_df[(results_df['dcable'] == opt_dcable) & (results_df['number_of_turbines'] == opt_number_of_turbines)]
pivot_table = subset_df.pivot(index='prated', columns='radius', values='lcoe')
plot_heatmap(pivot_table.columns, pivot_table.index, pivot_table.values, 'Radius', 'Prated', axs[0], 'LCOE')

# Heatmap with x and y axis as radius and dcable
subset_df = results_df[(results_df['prated'] == opt_prated) & (results_df['number_of_turbines'] == opt_number_of_turbines)]
pivot_table = subset_df.pivot(index='dcable', columns='radius', values='lcoe')
plot_heatmap(pivot_table.columns, pivot_table.index, pivot_table.values, 'Radius', 'Dcable', axs[1], 'LCOE')

# Heatmap with x and y axis as radius and number of turbines
subset_df = results_df[(results_df['prated'] == opt_prated) & (results_df['dcable'] == opt_dcable)]
pivot_table = subset_df.pivot(index='number_of_turbines', columns='radius', values='lcoe')
plot_heatmap(pivot_table.columns, pivot_table.index, pivot_table.values, 'Radius', 'Number of Turbines', axs[2], 'LCOE')

# Heatmap with x and y axis as prated and dcable
subset_df = results_df[(results_df['radius'] == opt_radius) & (results_df['number_of_turbines'] == opt_number_of_turbines)]
pivot_table = subset_df.pivot(index='prated', columns='dcable', values='lcoe')
plot_heatmap(pivot_table.columns, pivot_table.index, pivot_table.values, 'Dcable', 'Prated', axs[3], 'LCOE')

# Heatmap with x and y axis as prated and number of turbines
subset_df = results_df[(results_df['radius'] == opt_radius) & (results_df['dcable'] == opt_dcable)]
pivot_table = subset_df.pivot(index='number_of_turbines', columns='prated', values='lcoe')
plot_heatmap(pivot_table.columns, pivot_table.index, pivot_table.values, 'Prated', 'Number of Turbines', axs[4], 'LCOE')

# Heatmap with x and y axis as dcable and number of turbines
subset_df = results_df[(results_df['radius'] == opt_radius) & (results_df['prated'] == opt_prated)]
pivot_table = subset_df.pivot(index='number_of_turbines', columns='dcable', values='lcoe')
plot_heatmap(pivot_table.columns, pivot_table.index, pivot_table.values, 'Dcable', 'Number of Turbines', axs[5], 'LCOE')

plt.tight_layout()
plt.savefig('heatmaps_lcoe_horizontal.png')
plt.show()

# Print the optimal values
print(f"Optimal Radius: {opt_radius}")
print(f"Optimal Prated: {opt_prated}")
print(f"Optimal Dcable: {opt_dcable}")
print(f"Optimal Number of Turbines: {opt_number_of_turbines}")
print(f"Minimum LCOE: {min_lcoe['lcoe']}")
# Out:
# Optimal Radius: 1.0
# Optimal Prated: 5000.0
# Optimal Dcable: 6.0
# Optimal Number of Turbines: 10.0
# Minimum LCOE: 2.7426505580537923

# %%
# Extract the optimal values
min_lcoe = results_df.loc[results_df['lcoe'].idxmin()]
opt_radius = min_lcoe['radius']
opt_prated = min_lcoe['prated']
opt_dcable = min_lcoe['dcable']
opt_number_of_turbines = min_lcoe['number_of_turbines']

# Function to plot heatmap with title
def plot_heatmap(x_range, y_range, values, x_label, y_label, ax, title):
    # Create a custom colormap from the 'bone' colormap, excluding the lightest part
    bone_cmap = plt.get_cmap('bone')
    custom_bone_cmap = mcolors.LinearSegmentedColormap.from_list(
        'custom_bone', bone_cmap(np.linspace(0, 0.8, 256))
    )
    sns.heatmap(values, xticklabels=np.round(x_range, 2), yticklabels=np.round(y_range, 2), cmap=custom_bone_cmap, annot=True, ax=ax)
    ax.set_xlabel(x_label)
    ax.set_ylabel(y_label)
    ax.set_title(f'{title} Heatmap ({x_label} vs {y_label})')

# Plot individual cost functions in capex list
capex_columns = capex_df.columns

# Create subplots for the individual cost functions
fig, axs = plt.subplots(len(capex_columns), 6, figsize=(36, 5 * len(capex_columns)))

for i, col in enumerate(capex_columns):
    # Heatmap with x and y axis as radius and prated
    subset_df = results_df[(results_df['dcable'] == opt_dcable) & (results_df['number_of_turbines'] == opt_number_of_turbines)]
    pivot_table = subset_df.pivot(index='prated', columns='radius', values=col)
    plot_heatmap(pivot_table.columns, pivot_table.index, pivot_table.values, 'Radius', 'Prated', axs[i, 0], col)
    
    # Heatmap with x and y axis as radius and dcable
    subset_df = results_df[(results_df['prated'] == opt_prated) & (results_df['number_of_turbines'] == opt_number_of_turbines)]
    pivot_table = subset_df.pivot(index='dcable', columns='radius', values=col)
    plot_heatmap(pivot_table.columns, pivot_table.index, pivot_table.values, 'Radius', 'Dcable', axs[i, 1], col)
    
    # Heatmap with x and y axis as radius and number of turbines
    subset_df = results_df[(results_df['prated'] == opt_prated) & (results_df['dcable'] == opt_dcable)]
    pivot_table = subset_df.pivot(index='number_of_turbines', columns='radius', values=col)
    plot_heatmap(pivot_table.columns, pivot_table.index, pivot_table.values, 'Radius', 'Number of Turbines', axs[i, 2], col)
    
    # Heatmap with x and y axis as prated and dcable
    subset_df = results_df[(results_df['radius'] == opt_radius) & (results_df['number_of_turbines'] == opt_number_of_turbines)]
    pivot_table = subset_df.pivot(index='prated', columns='dcable', values=col)
    plot_heatmap(pivot_table.columns, pivot_table.index, pivot_table.values, 'Dcable', 'Prated', axs[i, 3], col)
    
    # Heatmap with x and y axis as prated and number of turbines
    subset_df = results_df[(results_df['radius'] == opt_radius) & (results_df['dcable'] == opt_dcable)]
    pivot_table = subset_df.pivot(index='number_of_turbines', columns='prated', values=col)
    plot_heatmap(pivot_table.columns, pivot_table.index, pivot_table.values, 'Prated', 'Number of Turbines', axs[i, 4], col)
    
    # Heatmap with x and y axis as dcable and number of turbines
    subset_df = results_df[(results_df['radius'] == opt_radius) & (results_df['prated'] == opt_prated)]
    pivot_table = subset_df.pivot(index='number_of_turbines', columns='dcable', values=col)
    plot_heatmap(pivot_table.columns, pivot_table.index, pivot_table.values, 'Dcable', 'Number of Turbines', axs[i, 5], col)

plt.tight_layout()
plt.savefig('heatmaps_cost_extended.png')
plt.show()

# %%
# Extract the optimal values
min_lcoe = results_df.loc[results_df['lcoe'].idxmin()]
opt_radius = min_lcoe['radius']
opt_prated = min_lcoe['prated']
opt_dcable = min_lcoe['dcable']
opt_number_of_turbines = min_lcoe['number_of_turbines']

# Function to plot heatmap with title
def plot_heatmap(x_range, y_range, values, x_label, y_label, ax, title):
    bone_cmap = plt.get_cmap('bone')
    custom_bone_cmap = mcolors.LinearSegmentedColormap.from_list(
        'custom_bone', bone_cmap(np.linspace(0, 0.8, 256))
    )
    sns.heatmap(values, xticklabels=np.round(x_range, 2), yticklabels=np.round(y_range, 2), cmap=custom_bone_cmap, annot=True, ax=ax)
    ax.set_xlabel(x_label)
    ax.set_ylabel(y_label)
    ax.set_title(f'{title} Heatmap ({x_label} vs {y_label})')

# Create subplots for the heatmaps
fig, axs = plt.subplots(2, 6, figsize=(36, 16))

# Define the variable pairs and titles
variable_pairs = [
    ('radius', 'prated', 'Annual Energy'),
    ('radius', 'dcable', 'Annual Energy'),
    ('radius', 'number_of_turbines', 'Annual Energy'),
    ('prated', 'dcable', 'Annual Energy'),
    ('prated', 'number_of_turbines', 'Annual Energy'),
    ('dcable', 'number_of_turbines', 'Annual Energy'),
    ('radius', 'prated', 'Capacity Factor'),
    ('radius', 'dcable', 'Capacity Factor'),
    ('radius', 'number_of_turbines', 'Capacity Factor'),
    ('prated', 'dcable', 'Capacity Factor'),
    ('prated', 'number_of_turbines', 'Capacity Factor'),
    ('dcable', 'number_of_turbines', 'Capacity Factor')
]

# Define the optimal values
optimal_values = {
    'radius': opt_radius,
    'prated': opt_prated,
    'dcable': opt_dcable,
    'number_of_turbines': opt_number_of_turbines
}

# Plot the heatmaps
for i, (x_var, y_var, title) in enumerate(variable_pairs):
    row = i // 6
    col = i % 6
    subset_df = results_df.copy()
    for var in optimal_values:
        if var != x_var and var != y_var:
            subset_df = subset_df[subset_df[var] == optimal_values[var]]
    pivot_table = subset_df.pivot(index=y_var, columns=x_var, values=title.lower().replace(' ', '_'))
    plot_heatmap(pivot_table.columns, pivot_table.index, pivot_table.values, x_var.capitalize(), y_var.capitalize(), axs[row, col], title)

plt.tight_layout()
plt.savefig('heatmaps_annual_energy_capacity_factor.png')
plt.show()

# %%
# Extract the optimal values
min_lcoe = results_df.loc[results_df['lcoe'].idxmin()]
opt_radius = min_lcoe['radius']
opt_prated = min_lcoe['prated']
opt_dcable = min_lcoe['dcable']
opt_number_of_turbines = min_lcoe['number_of_turbines']

# Function to plot heatmap with title
def plot_heatmap(x_range, y_range, values, x_label, y_label, ax, title):
    bone_cmap = plt.get_cmap('bone')
    custom_bone_cmap = mcolors.LinearSegmentedColormap.from_list(
        'custom_bone', bone_cmap(np.linspace(0, 0.8, 256))
    )
    sns.heatmap(values, xticklabels=np.round(x_range, 2), yticklabels=np.round(y_range, 2), cmap=custom_bone_cmap, annot=True, ax=ax)
    ax.set_xlabel(x_label)
    ax.set_ylabel(y_label)
    ax.set_title(f'{title} Heatmap ({x_label} vs {y_label})')

# Create subplots for the heatmaps
fig, axs = plt.subplots(2, 6, figsize=(36, 16))

# Define the variable pairs and titles
variable_pairs = [
    ('radius', 'prated', 'num_batteries_charged'),
    ('radius', 'dcable', 'num_batteries_charged'),
    ('radius', 'number_of_turbines', 'num_batteries_charged'),
    ('prated', 'dcable', 'num_batteries_charged'),
    ('prated', 'number_of_turbines', 'num_batteries_charged'),
    ('dcable', 'number_of_turbines', 'num_batteries_charged'),
    ('radius', 'prated', 'charge_time_average'),
    ('radius', 'dcable', 'charge_time_average'),
    ('radius', 'number_of_turbines', 'charge_time_average'),
    ('prated', 'dcable', 'charge_time_average'),
    ('prated', 'number_of_turbines', 'charge_time_average'),
    ('dcable', 'number_of_turbines', 'charge_time_average')
]

# Define the optimal values
optimal_values = {
    'radius': opt_radius,
    'prated': opt_prated,
    'dcable': opt_dcable,
    'number_of_turbines': opt_number_of_turbines
}

# Plot the heatmaps
for i, (x_var, y_var, title) in enumerate(variable_pairs):
    row = i // 6
    col = i % 6
    subset_df = results_df.copy()
    for var in optimal_values:
        if var != x_var and var != y_var:
            subset_df = subset_df[subset_df[var] == optimal_values[var]]
    pivot_table = subset_df.pivot(index=y_var, columns=x_var, values=title.lower())
    plot_heatmap(pivot_table.columns, pivot_table.index, pivot_table.values, x_var.capitalize(), y_var.capitalize(), axs[row, col], title)

plt.tight_layout()
plt.savefig('heatmaps_battery.png')
plt.show()

# %%
results_df
results_df.to_excel('results_df.xlsx', index=False)
